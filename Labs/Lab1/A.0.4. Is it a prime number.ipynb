# %% [markdown]
# # Lab1: This Python script solves the problems outlined in assignment A.0.4. Is it a prime number?
#
# Task description:
#
#  A prime number is an integer greater than 1 that is only divisible by one and itself. Write a function that determines whether or not its parameter is prime, returning True if it is, and False otherwise. Write a main program that reads an integer from the user and displays a message indicating whether or not it is prime.
#
# # Author: Anders Grahn
# # Date: 2024-01-20

# %%
from prime_number import check_if_prime_number

# Message to to show if it is not a prime number
message_this_is_not_a_prime_number = "This is not a prime number"
# Message to to show if it is a prime number
message_this_is_a_prime_nuber = "This is a prime number"

# Read the user input
print("What number do you want to check to see if it is a prime number: ", end ="")
user_input_number = int(input())
print(user_input_number)

# Check if the user entered a prime number
if check_if_prime_number(user_input_number):
  print(message_this_is_a_prime_nuber)
else:
  print(message_this_is_not_a_prime_number)
# Out:
# What number do you want to check to see if it is a prime number: 134
# This is not a prime number
